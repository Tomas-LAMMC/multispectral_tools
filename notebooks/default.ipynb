# %%
import sys
import os

# Get the folder one level up from your notebook
module_path = os.path.abspath(os.path.join('..')) 

if module_path not in sys.path:
    # Insert at index 0 to override site-packages
    sys.path.insert(0, module_path)

import micasense
print(f"SUCCESS! Using library from: {micasense.__file__}")
# Out:
# SUCCESS! Using library from: c:\Python\multispectral_tools\micasense\__init__.py
